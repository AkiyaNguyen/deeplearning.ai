# %%
# %pip install torch torchvision numpy matplotlib torchinfo
# Out:
# ...
#   Using cached torch-2.7.1-cp39-cp39-win_amd64.whl.metadata (28 kB)
# ...
#   Using cached torchvision-0.22.1-cp39-cp39-win_amd64.whl.metadata (6.1 kB)
# ...
# Using cached torch-2.7.1-cp39-cp39-win_amd64.whl (216.0 MB)
# Using cached torchvision-0.22.1-cp39-cp39-win_amd64.whl (1.7 MB)
# ...
#
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
# ...

# %%
# %pip install torchsummary
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import torch.nn as nn
import torch
import torch.nn.functional as F
from torchsummary import summary
class MNISTClassifer(nn.Module):
    def __init__(self, in_features, out_features, num_hiddens, hidden_features):
        super().__init__()
        
        layer = [nn.Linear(in_features, hidden_features), ]

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(3, 6, 5)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(6, 16, 5)
        self.fc1 = nn.Linear(16 * 5 * 5, 120)
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, 10)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = x.view(-1, 16 * 5 * 5)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

net = Net()
print(net)
print(net.state_dict())
summary(net,(3, 32, 32))
# Out:
# Net(
#   (conv1): Conv2d(3, 6, kernel_size=(5, 5), stride=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(6, 16, kernel_size=(5, 5), stride=(1, 1))
#   (fc1): Linear(in_features=400, out_features=120, bias=True)
#   (fc2): Linear(in_features=120, out_features=84, bias=True)
#   (fc3): Linear(in_features=84, out_features=10, bias=True)
# )
# OrderedDict([('conv1.weight', tensor([[[[-8.8931e-02,  5.2654e-04, -6.8445e-02, -1.5540e-02, -9.5778e-02],
#           [ 1.1504e-01, -6.2052e-02,  1.0981e-01,  9.3486e-02, -6.1289e-02],
#           [ 5.7411e-03, -3.8132e-02, -7.9352e-02, -1.1363e-01, -4.7548e-03],
#           [-6.3737e-02,  6.8900e-02,  4.8010e-02,  1.9854e-02,  9.8048e-03],
#           [-8.3578e-02, -5.7944e-02,  3.1033e-02, -4.0975e-02,  7.9729e-02]],
#
#          [[-4.6767e-02, -1.1401e-01,  3.6238e-02,  5.6298e-02, -8.4397e-02],
#           [-1.3113e-02, -4.1343e-02, -1.1207e-01,  7.9584e-02,  9.9908e-02],
# ...

# %%
a = torch.zeros((128,1,28,28))
model = nn.Sequential(
    # nn.Linear(input_dim, hidden_dim),
    # nn.ReLU(),
    nn.Conv2d(1, 5, 5),
    ##  (B, 5, 24, 24)
    nn.MaxPool2d(2, 2),
    ## (B, 5, 12, 12)
    nn.Conv2d(5, 10, 5),
    ## (B, 10, 8, 8)
    nn.Flatten(),
    ## (B, 10 * 8 * 8)
    nn.Linear(10 * 8 * 8,  600),
    ## (B, 120)
    nn.Linear(600, 300)
    ## (B, 60)   
)
print(model(a).shape)
# Out:
# torch.Size([128, 300])
